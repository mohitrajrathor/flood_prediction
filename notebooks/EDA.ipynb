# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Loading data and Performing Discriptive Analysis

# %%
df = pd.read_csv('../data/raw/train.csv')
df.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117957 entries, 0 to 1117956
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id                               1117957 non-null  int64
#  1   MonsoonIntensity                 1117957 non-null  int64
#  2   TopographyDrainage               1117957 non-null  int64
#  3   RiverManagement                  1117957 non-null  int64
#  4   Deforestation                    1117957 non-null  int64
#  5   Urbanization                     1117957 non-null  int64
#  6   ClimateChange                    1117957 non-null  int64
#  7   DamsQuality                      1117957 non-null  int64
#  8   Siltation                        1117957 non-null  int64
#  9   AgriculturalPractices            1117957 non-null  int64
#  10  Encroachments                    1117957 non-null  int64
# ...

# %%
df.describe().round(2)
# Out:
#                id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1117957.00        1117957.00          1117957.00       1117957.00
# mean    558978.00              4.92                4.93             4.96
# std     322726.53              2.06                2.09             2.07
# min          0.00              0.00                0.00             0.00
# 25%     279489.00              3.00                3.00             4.00
# 50%     558978.00              5.00                5.00             5.00
# 75%     838467.00              6.00                6.00             6.00
# max    1117956.00             16.00               18.00            16.00
#
#        Deforestation  Urbanization  ClimateChange  DamsQuality   Siltation  \
# count     1117957.00    1117957.00     1117957.00   1117957.00  1117957.00
# mean            4.94          4.94           4.93         4.96        4.93
# std             2.05          2.08           2.06         2.08        2.07
# ...

# %% [markdown]
# ### 2. Relationship Between features

# %%
df.corr()
# Out:
#                                        id  MonsoonIntensity  \
# id                               1.000000         -0.000093
# MonsoonIntensity                -0.000093          1.000000
# TopographyDrainage              -0.001518         -0.007362
# RiverManagement                 -0.000413         -0.008070
# Deforestation                   -0.000080         -0.007251
# Urbanization                     0.000580         -0.009309
# ClimateChange                   -0.000188         -0.008031
# DamsQuality                      0.000133         -0.007787
# Siltation                        0.000281         -0.007836
# AgriculturalPractices           -0.000103         -0.008232
# Encroachments                   -0.000147         -0.010309
# IneffectiveDisasterPreparedness -0.000208         -0.008032
# DrainageSystems                  0.000558         -0.009716
# CoastalVulnerability            -0.001386         -0.010659
# Landslides                       0.001078         -0.009121
# ...
